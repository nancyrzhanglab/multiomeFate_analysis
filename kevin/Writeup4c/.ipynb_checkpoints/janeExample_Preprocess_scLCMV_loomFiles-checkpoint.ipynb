# %% [markdown]
# # Load packages

# %%
import scvelo as scv
import loompy
import velocyto as vcy
import pandas as pd
import scanpy as sc
scv.logging.print_version()
print(loompy.__version__)
# Out:
# Running scvelo 0.2.2 (python 3.7.6) on 2020-08-04 22:10.
# 2.0.17

# %%
scv.settings.verbosity = 3 # show errors(0), warnings(1), info(2), hints(3)
scv.settings.presenter_view = True # set max width size for presenter view
scv.set_figure_params('scvelo') # for beautified visualization

# %% [markdown]
# # Main preprocess

# %% [markdown]
# ## Generate new

# %% [markdown]
# #### scR103

# %%
## Need change
ladata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR103_counts.loom",validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
ladata.var_names_make_unique()

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4202 × 31053
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
clust = ["scR103" for x in range(ladata.shape[0])]
clust = pd.Categorical(clust)
ladata.obs['clusters'] = clust

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4202 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
ladata.write_loom("data/scRNAseq_velocyto_loomFiles/scR103_counts_new.loom")

# %% [markdown]
# #### scR104

# %%
## Need change
ladata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR104_counts.loom",validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
ladata.var_names_make_unique()

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 2846 × 31053
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
clust = ["scR104" for x in range(ladata.shape[0])]
clust = pd.Categorical(clust)
ladata.obs['clusters'] = clust

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 2846 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
ladata.write_loom("data/scRNAseq_velocyto_loomFiles/scR104_counts_new.loom")

# %% [markdown]
# #### scR105

# %%
## Need change
ladata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR105_counts.loom",validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
ladata.var_names_make_unique()

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4331 × 31053
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
clust = ["scR105" for x in range(ladata.shape[0])]
clust = pd.Categorical(clust)
ladata.obs['clusters'] = clust

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4331 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
ladata.write_loom("data/scRNAseq_velocyto_loomFiles/scR105_counts_new.loom")

# %% [markdown]
# #### scR106

# %%
## Need change
ladata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR106_counts.loom",validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
ladata.var_names_make_unique()

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4192 × 31053
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
clust = ["scR106" for x in range(ladata.shape[0])]
clust = pd.Categorical(clust)
ladata.obs['clusters'] = clust

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4192 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
ladata.write_loom("data/scRNAseq_velocyto_loomFiles/scR106_counts_new.loom")

# %% [markdown]
# #### scR107

# %%
## Need change
ladata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR107_counts.loom",validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
ladata.var_names_make_unique()

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 3856 × 31053
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
clust = ["scR107" for x in range(ladata.shape[0])]
clust = pd.Categorical(clust)
ladata.obs['clusters'] = clust

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 3856 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
ladata.write_loom("data/scRNAseq_velocyto_loomFiles/scR107_counts_new.loom")

# %% [markdown]
# #### scR108

# %%
## Need change
ladata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR108_counts.loom",validate=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
ladata.var_names_make_unique()

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4468 × 31053
#     obs: 'Clusters', '_X', '_Y'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
clust = ["scR108" for x in range(ladata.shape[0])]
clust = pd.Categorical(clust)
ladata.obs['clusters'] = clust

# %%
ladata
# Out:
# AnnData object with n_obs × n_vars = 4468 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
## Need change
ladata.write_loom("data/scRNAseq_velocyto_loomFiles/scR108_counts_new.loom")

# %% [markdown]
# ## Combine acute

# %%
loompy.combine(["data/scRNAseq_velocyto_loomFiles/scR101_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR102_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR103_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR104_counts_new.loom"],
                "data/scRNAseq_velocyto_loomFiles/scR101234_counts.loom", key="Accession")
# Out:
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459

# %%
adata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR101234_counts.loom")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 19600 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
adata.obs['clusters'] = pd.Categorical(adata.obs['clusters'])

# %%
scv.pl.proportions(adata)

# %% [markdown]
# ## Combine chronic

# %%
loompy.combine(["data/scRNAseq_velocyto_loomFiles/scR101_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR105_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR106_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR107_counts_new.loom"],
                "data/scRNAseq_velocyto_loomFiles/scR101567_counts.loom", key="Accession")
# Out:
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459

# %%
adata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scR101567_counts.loom")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 19642 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
adata.obs['clusters'] = pd.Categorical(adata.obs['clusters'])

# %%
scv.pl.proportions(adata)

# %% [markdown]
# ## Combine 8 dataset

# %%
loompy.combine(["data/scRNAseq_velocyto_loomFiles/scR101_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR102_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR103_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR104_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR105_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR106_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR107_counts_new.loom",
                "data/scRNAseq_velocyto_loomFiles/scR108_counts_new.loom"],
                "data/scRNAseq_velocyto_loomFiles/scRCombined_counts.loom", key="Accession")
# Out:
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# WARNING:root:╰──> at /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/loompy/loompy.py, line 459
# WARNING:root:╭── 'batch_scan_layers' is deprecated. Use 'scan' instead
# ...

# %%
adata = scv.read_loom("data/scRNAseq_velocyto_loomFiles/scRCombined_counts.loom")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 36447 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
scv.pl.proportions(adata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-bdce646225e8> in <module>
# ----> 1 scv.pl.proportions(adata)
#
# /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/scvelo/plotting/proportions.py in proportions(adata, groupby, layers, highlight, add_labels_pie, add_labels_bar, fontsize, figsize, dpi, use_raw, show)
#     100     if groupby is not None and groupby in adata.obs.keys():
#     101         counts_groups = dict()
# --> 102         for cluster in adata.obs[groupby].cat.categories:
#     103             counts_groups[cluster] = np.mean(
#     104                 counts_layers[:, adata.obs[groupby] == cluster], axis=1
#
# /opt/anaconda3/envs/batchwork/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# ...

# %%
adata.obs['clusters'] = pd.Categorical(adata.obs['clusters'])

# %%
scv.pl.proportions(adata)

# %%
adata.write_loom("data/scRNAseq_velocyto_loomFiles/scRCombined_counts_new.loom")

# %% [markdown]
# ## Subset 3k cells

# %%
import random

# %%
adata.shape[0]
# Out:
# 36447

# %%
random.seed(7)
subind = random.sample(range(adata.shape[0]), 15000)

# %%
subind[1:10]
# Out:
# [9886, 25875, 3164, 4747, 35119, 6168, 23965, 3801, 33255]

# %%
adata_subset = adata[subind,:]

# %%
adata_subset
# Out:
# View of AnnData object with n_obs × n_vars = 15000 × 31053
#     obs: 'Clusters', '_X', '_Y', 'clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
adata_subset.obs['clusters'].shape
# Out:
# (15000,)

# %%
adata_subset.layers['spliced'].shape
# Out:
# (15000, 31053)

# %%
adata_subset.write_loom("data/scRNAseq_velocyto_loomFiles/scRCombined_subsamp15k_counts.loom")

# %%
scv.pl.proportions(adata_subset)
